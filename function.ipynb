# %%
def sumfn(m,n):
 add=m+n
 print(add)
a=10
b=20
(sumfn(a,b))
print(sumfn(a,b))
# Out:
# 30
# 30
# None

# %%
def sumfn(m,n):
 add=m+n
 return add
a=10
b=20
c=sumfn(a,b)
print(c)
# Out:
# 30

# %%
def sumfn():
  a=10
  b=20
  add=a+b
  print(add)
sumfn()
# Out:
# 30

# %%
def sumfn():
  a=10
  b=20
  add=a+b
  return add
print(sumfn())
# Out:
# 30

# %%
def sumfn(a,b):
 add=a+b

 print(add)
a=int(input("enter a value"))
b=int(input("enter b value"))
sumfn(a,b)
# Out:
# enter a value2
# enter b value2
# 4
