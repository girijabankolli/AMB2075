# %%
soil_moisture=[45,60,30,55,40]
print(("soil moisture levels in different fields"))
for moisture in soil_moisture:
  print(moisture,"%")
# Out:
# soil moisture levels in different fields
# 45 %
# 60 %
# 30 %
# 55 %
# 40 %

# %%
if(moisture<50):
  print("%irrigation neeeded")
else:
  print("sufficient moisture")
# Out:
# %irrigation neeeded

# %%
print("total field checked",len(soil_moisture))
# Out:
# total field checked 9

# %%
soil_moisture.append(65)
print("after adding new moisture level",soil_moisture)
# Out:
# after adding new moisture level [40, 45, 55, 60, 65, 65, 65, 65, 65, 66, 65, 65]

# %%
print("total field checked",len(soil_moisture))
# Out:
# total field checked 12

# %%
soil_moisture.remove(65)
print(soil_moisture)
# Out:
# [40, 45, 55, 60, 65, 65, 65, 65, 66, 65, 65]

# %%
print("total field checked",len(soil_moisture))
# Out:
# total field checked 11

# %%
soil_moisture.sort()
print(soil_moisture)
# Out:
# [40, 45, 55, 60, 65, 65, 65, 65, 65, 65, 66]

# %%
max(soil_moisture)
print("maximum level of soil moisture is",max(soil_moisture),"%")
min(soil_moisture)
print("minimum level of soil moisture is",min(soil_moisture),"%")
# Out:
# maximum level of soil moisture is 66 %
# minimum level of soil moisture is 40 %

# %%
names=["laxmi","radha","rama"]
age=[20,21,22]
for i in range(len(names)):
 print(names[i],"age is",age[i])
# Out:
# laxmi age is 20
# radha age is 21
# rama age is 22

# %%
for n,a in zip(names,age):
  print(n ,"age is",a)
# Out:
# laxmi age is 20
# radha age is 21
# rama age is 22

# %%
crops=["rice","wheat","maize"]
water_need=[100,200,300]
print(len(crops))
# Out:
# 3

# %%
print(range(len(crops)))
# Out:
# range(0, 3)

# %%
print("crops water requirement")
print( crops[i],"require",water_need[i],"mm")
# Out:
# crops water requirement
# maize require 300 mm

# %%
for c,w in zip(crops,water_need):
  print(c)
# Out:
# rice
# wheat
# maize

# %%
for crop,w in zip(crops,water_need):
   if w>180:
    print(crop)
# Out:
# wheat
# maize

# %%
crops=["rice","wheat","maize"]
yield_tons=[4.0,3.5,2.8,1.5]
average_yield =sum(yield_tons)/len(yield_tons)
print(average_yield)
# Out:
# 2.95
