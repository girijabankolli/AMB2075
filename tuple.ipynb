# %%
t=("hi","hlo","uu",88,56)
print(t)
print(len(t))
print(type(t))
# Out:
# ('hi', 'hlo', 'uu', 88, 56)
# 5
# <class 'tuple'>

# %%
t=("hi","hlo","uu",88,56)
i=0
print("")
while i<len(t):
 print(t[i])
 i+=1
# Out:
# hi
# hlo
# uu
# 88
# 56

# %%
print(" ")
for s in t:
   print(s)
# Out:
#
# hi
# hlo
# uu
# 88
# 56

# %%
t=(3,4,5,6,7,8)
print("t1",t[0])
print("t2",t[1])
print("t5",t[-1])
# Out:
# t1 3
# t2 4
# t5 8

# %%
t=(3,6,5,6,8)
print(t[1:3])
# Out:
# (6, 5)

# %%
print(t[2:1])
# Out:
# ()

# %%
print(t[ :2])
# Out:
# (3, 6)

# %%
print(t[ :-1])
# Out:
# (3, 6, 5, 6)

# %%
print(t[-4:-4])
# Out:
# ()

# %%
print(t[-3:-5])
# Out:
# ()

# %%
type(t)
# Out:
# tuple

# %%
t.append
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-4249967897.py in <cell line: 0>()
# ----> 1 t.append
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
t.insert
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-840557984.py in <cell line: 0>()
# ----> 1 t.insert
#
# AttributeError: 'tuple' object has no attribute 'insert'

# %%
t.add
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1006083792.py in <cell line: 0>()
# ----> 1 t.add
#
# AttributeError: 'tuple' object has no attribute 'add'

# %%
t.extend
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2349033263.py in <cell line: 0>()
# ----> 1 t.extend
#
# AttributeError: 'tuple' object has no attribute 'extend'

# %%
del t[2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3430130672.py in <cell line: 0>()
# ----> 1 del t[2]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
t=(4,5,67,7,78,878)
t1=list(t)
t1.append("kjgj")
t=tuple(t1)
print("")
print("after adding",t)
# Out:
# after adding (4, 5, 67, 7, 78, 878, 'kjgj')

# %%
t1=list(t)
t1.insert(3,"jhnj")
t=tuple(t1)
print("aft inserting",t)
# Out:
# aft inserting (4, 5, 67, 'jhnj', 7, 78, 878, 'kjgj')

# %%
t1=list(t)
del t1[1]
t=tuple(t1)
print("after deleting",t)
# Out:
# after deleting (4, 67, 'jhnj', 7, 78, 878, 'kjgj')

# %%
t=(4,5,67,7,78,878)
sum(t)
# Out:
# 1039

# %%
sum(t)/len(t)
# Out:
# 173.16666666666666

# %%
sum(t)//len(t)
# Out:
# 173

# %%
max(t)
# Out:
# 878

# %%
min(t)
# Out:
# 4

# %%
5 in t
# Out:
# True

# %%
5 not in t
# Out:
# False

# %%
"hg" in t
# Out:
# False

# %%
type(t)
# Out:
# tuple

# %%
t1=(4,5,7,3,4)
t2=(2,4,5,9,0)
t3=t1+t2
print(t3)
# Out:
# (4, 5, 7, 3, 4, 2, 4, 5, 9, 0)

# %%
t4=t1+t3
print(t4)
# Out:
# (4, 5, 7, 3, 4, 4, 5, 7, 3, 4, 2, 4, 5, 9, 0)

# %%
t1=(4,5,7,3,4)
t2=(2,4,5,9,0)
t3=t1[1:4]+t2[1:2]
print(t3)
# Out:
# (5, 7, 3, 4)

# %%
t1.index(4)
# Out:
# 0

# %%
t1.index(6)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1674557640.py in <cell line: 0>()
# ----> 1 t1.index(6)
#
# ValueError: tuple.index(x): x not in tuple

# %%
t.count(4)
# Out:
# 1

# %%
t1.count(4)
# Out:
# 2

# %%
t1.count(87)
# Out:
# 0

# %%
t1=[4,5,7,3,4]
print(id(t1))
t1.append(9)
print(id(t1))
# Out:
# 139089559351808
# 139089559351808

# %%
s1={3,4,5,}
print(id(s1))
s1.add(8)
print(id(s1))
# Out:
# 139089560902496
# 139089560902496

# %%
d1={1:45,3:56,7:89}
print(id(d1))
d1[2]=90
print(id(d1))
# Out:
# 139089550703424
# 139089550703424

# %%
a="wer"
id(a)
# Out:
# 139089549176832

# %%
a=a+"gh"
id(a)
# Out:
# 139089549180720

# %%
b=a+"jyt"
id(b)
# Out:
# 139089565079920

# %%
b[4]
# Out:
# 'h'

# %%
b="gcfhj"
b[0]="j"
print(b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2851561645.py in <cell line: 0>()
#       1 b="gcfhj"
# ----> 2 b[0]="j"
#       3 print(b)
#
# TypeError: 'str' object does not support item assignment

# %%
x=5
id(x)
# Out:
# 11654504

# %%
x=8+9
id(x)
# Out:
# 11654888

# %%
y=x
id(y)
# Out:
# 11654888
