# %%
file=open("gkvk.txt","w")
file.write("hi......")
file.close()

# %%
file=open("gkvk.txt","r")
content=file.read()
print(content)
file.close()
# Out:
# hi......

# %%
file=open("gkvk.txt","a")
file.write("hi...... how r u..?")
file.close()

# %%
file=open("gkvk.txt","r")
content=file.read()
print(content)
file.close()
# Out:
# hi......hi...... how r u..?

# %%
file=open("gkvk.txt","r")
content=file.readline()
print(content)
file.close()
# Out:
# hi......hi...... how r u..?

# %%
with open("gkvk.txt","r") as file:
    print(file.read())
# Out:
# hi......hi...... how r u..?hi...... how r u..?

# %%
with open("gkvk.txt","w") as file:
    file.write("hfffffffffffffffufhr")

# %%
with open("gkvk.txt","r") as file:
    print(file.read())
# Out:
# hfffffffffffffffufhr
