# %%
a=1
print(type(a))
# Out:
# <class 'int'>

# %%
a=5.6
print(type(a))
# Out:
# <class 'float'>

# %%
a="fffff"
print(type(a))
# Out:
# <class 'str'>

# %%
a=[5656,90,89]
print(type(a))
# Out:
# <class 'list'>

# %%
a=(67,78,78)
print(type(a))
# Out:
# <class 'tuple'>

# %%
a=232
print("value of a is",a)
print(type(a))
# Out:
# value of a is 232
# <class 'int'>

# %%
a=77
b=89
print("value of a and b are {} and {} ". format(a,b))
# Out:
# value of a and b are 77 and 89

# %%
a=56
b=89
print("value of a and b are,{0}  and{1}".format(a,b))
# Out:
# value of a and b are,56  and89

# %%
print("i love {1},{0} and {2}".format("mango","apple","banana"))
# Out:
# i love apple,mango and banana

# %%
print("today is {2},I'm {0} inside the{1}lab" .format("sitting" ,"cs","thursday"))
# Out:
# today is thursday,I'm sitting inside thecslab

# %%
a=int(input("enter a number"))
print(a)
print(type(a
           ))
# Out:
# enter a number7
# 7
# <class 'int'>

# %%
a=int(input("enter a number"))
b=int(input("enter another number"))
print(a*b)
print("product of{} and {} is,{}".format(a,b,c))
# Out:
# enter a number8
# enter another number9
# 72
# product of8 and 9 is,100

# %%
a=str(input("enter your name"))
b=int(input("enter your age"))
c=b+10
print("i am {}, my age afteer 10 years is{}".format(a,c))
# Out:
# enter your namekamakshi
# enter your age20
# i am kamakshi, my age afteer 10 years is30
