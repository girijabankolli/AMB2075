# %%
l1=[10,20,30,40,50,60]
print(l1[2:4])
print(l1[3:6])
print(l1[2:8])
print(l1[2:5])
print(l1[1:4])
# Out:
# [30, 40]
# [40, 50, 60]
# [30, 40, 50, 60]
# [30, 40, 50]
# [20, 30, 40]

# %%
l1[8]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-3132471691.py in <cell line: 0>()
# ----> 1 l1[8]
#
# IndexError: list index out of range

# %%
l1[0:4]
# Out:
# [10, 20, 30, 40]

# %%
l1[3: ]
# Out:
# [40, 50, 60]

# %%
l1[-4:-1]
# Out:
# [30, 40, 50]

# %%
l1[-3:-5]
# Out:
# []

# %%
l1[5:4]
# Out:
# []

# %%
l1[1:6:1]
# Out:
# [20, 30, 40, 50, 60]

# %%
l1[1:6:2]
# Out:
# [20, 40, 60]

# %%
l1[1:6:3]
# Out:
# [20, 50]

# %%
l1[4:6:-2]
# Out:
# []

# %%
n=[10,20,30,40,50,60]
n[-5:-1]
# Out:
# [20, 30, 40, 50]

# %%
n[-5:-1:2]
# Out:
# [20, 40]

# %%
c=["rice","wheat","maize","millet","pulses"]
print(c[ :5:2])
print(c[ : :-1])
# Out:
# ['rice', 'maize', 'pulses']
# ['pulses', 'millet', 'maize', 'wheat', 'rice']

# %%
l1=[10,20,30,40,50,60]
l1[4:2:-1]
# Out:
# [50, 40]

# %%
l1[-4:-2:-1]
# Out:
# []

# %%
l1[4:2:-1]
# Out:
# [50, 40]

# %%
l1[-5:-1:]
# Out:
# [20, 30, 40, 50]

# %%
l1[-5:-1:-1]
# Out:
# []

# %%
l1[-1:-5:-1]
# Out:
# [60, 50, 40, 30]
