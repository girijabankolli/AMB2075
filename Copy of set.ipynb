# %%
s={'a','e','b','b','q'}
print(s)
# Out:
# {'a', 'b', 'e', 'q'}

# %%
print("number of elements",len(s))
# Out:
# number of elements 4

# %%
print("type of the object",type(s))
# Out:
# type of the object <class 'set'>

# %%
print(s)
print("")
for i in s:
  print(i)
# Out:
# {'a', 'b', 'e', 'q'}
#
# a
# b
# e
# q

# %%
print(s[2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3674811518.py in <cell line: 0>()
# ----> 1 print(s[2])
#
# TypeError: 'set' object is not subscriptable

# %%
print(s)
s.add(78)
print("after adding",s)
# Out:
# {'hey...', 'b', 'e', 'q', 'a'}
# after adding {'hey...', 78, 'b', 'e', 'q', 'a'}

# %%
s1=('tyy',889)
s.update(s1)
print(s)
# Out:
# {'hey...', 78, 'tyy', 'b', 'e', 'q', 889, 'a'}

# %%
s.remove('b')
print(s)
# Out:
# {'hey...', 78, 'tyy', 'e', 'q', 889, 'a'}

# %%
s.discard('tyy')
print(s)
# Out:
# {'hey...', 78, 'e', 'q', 889, 'a'}

# %%
s.pop()
print(s)
# Out:
# {78, 'e', 'q', 889, 'a'}

# %%
s.clear()
print(s)
# Out:
# set()

# %%
del(s)

# %%
s={45,67,98,88,99}
print((s))
# Out:
# {98, 67, 99, 88, 45}

# %%
s={45,67,98,88,99}
print(sum(s))
# Out:
# 397

# %%
print("avg=",sum(s)/len(s))
# Out:
# avg= 79.4

# %%
print(max(s))
# Out:
# 99

# %%
print(min(s))
# Out:
# 45

# %%
a={65,78,90}
b={67,60,34,78}
print(a.union(b))
# Out:
# {65, 34, 67, 90, 60, 78}

# %%
print(a.intersection(b))
# Out:
# {78}

# %%
print(a.difference(b))
# Out:
# {65, 90}

# %%
print(b.difference(a))
# Out:
# {34, 67, 60}

# %%
print(a.symmetric_difference(b))
# Out:
# {65, 34, 67, 90, 60}

# %%
print(b.symmetric_difference(a))
# Out:
# {65, 34, 67, 90, 60}
