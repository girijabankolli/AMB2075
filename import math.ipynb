# %%
import math as m
m.exp(-200)
# Out:
# 1.3838965267367376e-87

# %%
m.exp(20)
# Out:
# 485165195.4097903

# %%
m.log(100,2)
# Out:
# 6.643856189774725

# %%
m.log(10,10)
# Out:
# 1.0

# %%
m.log(100,10)
# Out:
# 2.0

# %%
m.log10(100)
# Out:
# 2.0

# %%
m.cos(30)
# Out:
# 0.15425144988758405

# %%
m.tan(30)
# Out:
# -6.405331196646276

# %%
m.sin(30)
# Out:
# -0.9880316240928618

# %%
m.sqrt(324)
# Out:
# 18.0

# %%
m.ceil(23.898)
# Out:
# 24

# %%
m.ceil(435689.10)
# Out:
# 435690

# %%
m.floor(3165.8)
# Out:
# 3165
