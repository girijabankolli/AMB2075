# %%
list=[2,3,4,56,9,6,6]
print(list.pop())
print(list)
# Out:
# 6
# [2, 3, 4, 56, 9, 6]

# %%
print(list.remove(56))
print(list)
# Out:
# None
# [2, 3, 9, 6, 6]

# %%
print(list.clear())
print(list)
# Out:
# None
# []

# %%
[6,7,7]
del(list)
print(list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1575513311.py in <cell line: 0>()
#       1 [6,7,7]
# ----> 2 del(list)
#       3 print(list)
#
# NameError: name 'list' is not defined

# %%
list1=[23,21,98]
print(list1)
list1.sort()
print(list1)
print(max(list1))
print(min(list1))
# Out:
# [23, 21, 98]
# [21, 23, 98]
# 98
# 21

# %%
list=['a','G','k','j']
list.sort()
print(list)
# Out:
# ['G', 'a', 'j', 'k']

# %%
a=[3,5,6]
b=a
a.insert(8,9)
print("a",a)
print("b",b)
# Out:
# a [3, 5, 6, 9]
# b [3, 5, 6, 9]
