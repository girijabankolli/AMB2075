# %%
print(bool("helloo"))
print(bool(0))
print(bool(1))

# %%
i=1
while(i<=20):
  if i%2!=0:
    print(i)
  i+=1

# %%
i=1
if i%3==0:
  print(i)
  i+=1

# %%
i=1
while (i<=20):
  if i%3==0 :
    print(i)
    i+=1

# %%
print(7898)
